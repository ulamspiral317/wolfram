# %%
list = AnglePath@Flatten@Table[PadRight[{Pi/2}, Floor[n/2]], {n, 2, 200}];
Graphics[{White, Point@Table[list[[Prime@n]], {n, 1, 1229}]}, Background -> Black]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..."></div>
